# %%
import matplotlib.pyplot as plt

D = {'extract method': 5.0, 'inline method': 10.666666666666666, 'rename method': 22.166666666666675, 'move method': 719.8333333333334, 'move attribute': 109.74999999999999, 'pull up method': 667.5, 'pull up attribute': 32.91666666666667, 'push down method': 34.75, 'push down attribute': 18.75, 'extract superclass': 25.75, 'extract interface': 8.0, 'move class': 24.5, 'rename class': 24.25, 'extract and move method': 9.583333333333332, 'change package (move, rename, split, merge)': 0, 'move and rename class': 94.58333333333334, 'extract class': 48.0, 'extract subclass': 3.083333333333333, 'extract variable': 4.166666666666667, 'inline variable': 2.0, 'parameterize variable': 0, 'rename variable': 26.166666666666664, 'rename parameter': 35.33333333333335, 'rename attribute': 34.41666666666667, 'move and rename attribute': 0, 'replace variable with attribute': 2.9166666666666665, 'replace attribute (with attribute)': 0, 'merge variable': 2.333333333333333, 'merge parameter': 2.0, 'merge attribute': 0, 'split variable': 0, 'split parameter': 0, 'split attribute': 0.5, 'change variable type': 11.333333333333334, 'change parameter type': 98.33333333333334, 'change return type': 67.0, 'change attribute type': 35.0, 'extract attribute': 0.5, 'move and rename method': 90.75, 'move and inline method': 6.166666666666666, 'add method annotation': 32.499999999999986, 'remove method annotation': 20.833333333333336, 'modify method annotation': 0.25, 'add attribute annotation': 12.0, 'remove attribute annotation': 9.833333333333332, 'modify attribute annotation': 0, 'add class annotation': 4.416666666666666, 'remove class annotation': 5.666666666666666, 'modify class annotation': 6.166666666666667, 'add parameter annotation': 0, 'remove parameter annotation': 0, 'modify parameter annotation': 0, 'add variable annotation': 0, 'remove variable annotation': 3.0, 'modify variable annotation': 0, 'add parameter': 71.33333333333333, 'remove parameter': 44.25, 'reorder parameter': 3.5, 'add thrown exception type': 4.916666666666666, 'remove thrown exception type': 6.333333333333333, 'change thrown exception type': 4.333333333333333, 'change method access modifier': 32.0, 'change attribute access modifier': 37.75, 'encapsulate attribute': 3.083333333333333, 'parameterize attribute': 5.333333333333333, 'replace attribute with variable': 0}

plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))


plt.show()

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.style.use('seaborn-whitegrid')
def drawDict(value,name,outputPath):
#     value = sorted(dictData.items(),key = lambda item:item[1],reverse=False)
    x = []
    y = []
#     n=len(dictData);
    n=len(value)
    for each in value:
        x.append(each[0])
        y.append(each[1])
    plt.figure(figsize=(10, 10), dpi=600)
    plt.bar(x[0:n],y[0:n],label="RM detected RO")
#     plt.barh(x[0:n], y[0:n],label="RM detected RO")
    plt.ylabel("Number of RO generate because of squash")
    plt.xlabel("Type of RO")
    plt.title(name)
    plt.xticks(range(len(x)),x , rotation=90)
    outputPath=outputPath+name+".png"
    plt.savefig(outputPath,dpi=400,bbox_inches='tight')
    plt.show()

# %%
outputPath="/Users/leichen/ResearchAssistant/InteractiveRebase/data/DGrefTypeGraph/"
name = "All"
Dgenerated = {'extract method': 5.0, 'inline method': 10.666666666666666, 'rename method': 22.166666666666675, 'move method': 719.8333333333334, 'move attribute': 109.74999999999999, 'pull up method': 667.5, 'pull up attribute': 32.91666666666667, 'push down method': 34.75, 'push down attribute': 18.75, 'extract superclass': 25.75, 'extract interface': 8.0, 'move class': 24.5, 'rename class': 24.25, 'extract and move method': 9.583333333333332, 'change package (move, rename, split, merge)': 0, 'move and rename class': 94.58333333333334, 'extract class': 48.0, 'extract subclass': 3.083333333333333, 'extract variable': 4.166666666666667, 'inline variable': 2.0, 'parameterize variable': 0, 'rename variable': 26.166666666666664, 'rename parameter': 35.33333333333335, 'rename attribute': 34.41666666666667, 'move and rename attribute': 0, 'replace variable with attribute': 2.9166666666666665, 'replace attribute (with attribute)': 0, 'merge variable': 2.333333333333333, 'merge parameter': 2.0, 'merge attribute': 0, 'split variable': 0, 'split parameter': 0, 'split attribute': 0.5, 'change variable type': 11.333333333333334, 'change parameter type': 98.33333333333334, 'change return type': 67.0, 'change attribute type': 35.0, 'extract attribute': 0.5, 'move and rename method': 90.75, 'move and inline method': 6.166666666666666, 'add method annotation': 32.499999999999986, 'remove method annotation': 20.833333333333336, 'modify method annotation': 0.25, 'add attribute annotation': 12.0, 'remove attribute annotation': 9.833333333333332, 'modify attribute annotation': 0, 'add class annotation': 4.416666666666666, 'remove class annotation': 5.666666666666666, 'modify class annotation': 6.166666666666667, 'add parameter annotation': 0, 'remove parameter annotation': 0, 'modify parameter annotation': 0, 'add variable annotation': 0, 'remove variable annotation': 3.0, 'modify variable annotation': 0, 'add parameter': 71.33333333333333, 'remove parameter': 44.25, 'reorder parameter': 3.5, 'add thrown exception type': 4.916666666666666, 'remove thrown exception type': 6.333333333333333, 'change thrown exception type': 4.333333333333333, 'change method access modifier': 32.0, 'change attribute access modifier': 37.75, 'encapsulate attribute': 3.083333333333333, 'parameterize attribute': 5.333333333333333, 'replace attribute with variable': 0}
Ddisappear = {'extract method': 137.66666666666669, 'inline method': 58.16666666666667, 'rename method': 490.0833333333333, 'move method': 377.0833333333333, 'move attribute': 40.0, 'pull up method': 27.5, 'pull up attribute': 15.0, 'push down method': 175.75, 'push down attribute': 12.833333333333332, 'extract superclass': 9.833333333333334, 'extract interface': 14.833333333333332, 'move class': 269.0833333333333, 'rename class': 168.08333333333331, 'extract and move method': 64.83333333333334, 'change package (move, rename, split, merge)': 0, 'move and rename class': 42.0, 'extract class': 27.833333333333336, 'extract subclass': 7.166666666666667, 'extract variable': 64.58333333333334, 'inline variable': 31.333333333333332, 'parameterize variable': 12.583333333333334, 'rename variable': 169.16666666666666, 'rename parameter': 483.3333333333333, 'rename attribute': 148.83333333333337, 'move and rename attribute': 0, 'replace variable with attribute': 25.0, 'replace attribute (with attribute)': 0, 'merge variable': 0.33333333333333337, 'merge parameter': 18.166666666666664, 'merge attribute': 1.0, 'split variable': 0, 'split parameter': 6.0, 'split attribute': 1.0, 'change variable type': 541.1666666666667, 'change parameter type': 440.33333333333337, 'change return type': 517.1666666666666, 'change attribute type': 720.9166666666667, 'extract attribute': 6.666666666666667, 'move and rename method': 79.50000000000001, 'move and inline method': 27.666666666666664, 'add method annotation': 495.8333333333333, 'remove method annotation': 116.41666666666667, 'modify method annotation': 38.25, 'add attribute annotation': 6.000000000000001, 'remove attribute annotation': 14.166666666666668, 'modify attribute annotation': 16.5, 'add class annotation': 47.916666666666664, 'remove class annotation': 13.166666666666668, 'modify class annotation': 16.166666666666668, 'add parameter annotation': 35.0, 'remove parameter annotation': 19.0, 'modify parameter annotation': 2.0, 'add variable annotation': 0, 'remove variable annotation': 3.0, 'modify variable annotation': 0, 'add parameter': 302.5833333333333, 'remove parameter': 312.83333333333337, 'reorder parameter': 6.166666666666667, 'add thrown exception type': 27.583333333333336, 'remove thrown exception type': 10.00000000000002, 'change thrown exception type': 0, 'change method access modifier': 120.33333333333333, 'change attribute access modifier': 98.91666666666669, 'encapsulate attribute': 44.416666666666664, 'parameterize attribute': 6.166666666666667, 'replace attribute with variable': 18.083333333333336}
value = sorted(Ddisappear.items(),key = lambda item:item[1],reverse=True)
len(value)
# Out:
# 66

# %%
drawDict(value,"Alldisappear",outputPath)

# %%
AllRO ={'extract method': 1250, 'inline method': 497, 'rename method': 1454, 'move method': 1671, 'move attribute': 545, 'pull up method': 509, 'pull up attribute': 223, 'push down method': 239, 'push down attribute': 39, 'extract superclass': 144, 'extract interface': 73, 'move class': 1924, 'rename class': 504, 'extract and move method': 407, 'change package (move, rename, split, merge)': 0, 'move and rename class': 270, 'extract class': 181, 'extract subclass': 22, 'extract variable': 484, 'inline variable': 189, 'parameterize variable': 40, 'rename variable': 808, 'rename parameter': 1630, 'rename attribute': 697, 'move and rename attribute': 0, 'replace variable with attribute': 46, 'replace attribute (with attribute)': 0, 'merge variable': 2, 'merge parameter': 23, 'merge attribute': 9, 'split variable': 2, 'split parameter': 7, 'split attribute': 6, 'change variable type': 3048, 'change parameter type': 3253, 'change return type': 4045, 'change attribute type': 1657, 'extract attribute': 74, 'move and rename method': 329, 'move and inline method': 503, 'add method annotation': 3733, 'remove method annotation': 1244, 'modify method annotation': 309, 'add attribute annotation': 334, 'remove attribute annotation': 237, 'modify attribute annotation': 199, 'add class annotation': 524, 'remove class annotation': 267, 'modify class annotation': 127, 'add parameter annotation': 30, 'remove parameter annotation': 88, 'modify parameter annotation': 15, 'add variable annotation': 1, 'remove variable annotation': 0, 'modify variable annotation': 0, 'add parameter': 1250, 'remove parameter': 478, 'reorder parameter': 32, 'add thrown exception type': 173, 'remove thrown exception type': 510, 'change thrown exception type': 25, 'change method access modifier': 1075, 'change attribute access modifier': 0, 'encapsulate attribute': 0, 'parameterize attribute': 0, 'replace attribute with variable': 0}
Dgenerated = {'extract method': 5.0, 'inline method': 10.666666666666666, 'rename method': 22.166666666666675, 'move method': 719.8333333333334, 'move attribute': 109.74999999999999, 'pull up method': 667.5, 'pull up attribute': 32.91666666666667, 'push down method': 34.75, 'push down attribute': 18.75, 'extract superclass': 25.75, 'extract interface': 8.0, 'move class': 24.5, 'rename class': 24.25, 'extract and move method': 9.583333333333332, 'change package (move, rename, split, merge)': 0, 'move and rename class': 94.58333333333334, 'extract class': 48.0, 'extract subclass': 3.083333333333333, 'extract variable': 4.166666666666667, 'inline variable': 2.0, 'parameterize variable': 0, 'rename variable': 26.166666666666664, 'rename parameter': 35.33333333333335, 'rename attribute': 34.41666666666667, 'move and rename attribute': 0, 'replace variable with attribute': 2.9166666666666665, 'replace attribute (with attribute)': 0, 'merge variable': 2.333333333333333, 'merge parameter': 2.0, 'merge attribute': 0, 'split variable': 0, 'split parameter': 0, 'split attribute': 0.5, 'change variable type': 11.333333333333334, 'change parameter type': 98.33333333333334, 'change return type': 67.0, 'change attribute type': 35.0, 'extract attribute': 0.5, 'move and rename method': 90.75, 'move and inline method': 6.166666666666666, 'add method annotation': 32.499999999999986, 'remove method annotation': 20.833333333333336, 'modify method annotation': 0.25, 'add attribute annotation': 12.0, 'remove attribute annotation': 9.833333333333332, 'modify attribute annotation': 0, 'add class annotation': 4.416666666666666, 'remove class annotation': 5.666666666666666, 'modify class annotation': 6.166666666666667, 'add parameter annotation': 0, 'remove parameter annotation': 0, 'modify parameter annotation': 0, 'add variable annotation': 0, 'remove variable annotation': 3.0, 'modify variable annotation': 0, 'add parameter': 71.33333333333333, 'remove parameter': 44.25, 'reorder parameter': 3.5, 'add thrown exception type': 4.916666666666666, 'remove thrown exception type': 6.333333333333333, 'change thrown exception type': 4.333333333333333, 'change method access modifier': 32.0, 'change attribute access modifier': 37.75, 'encapsulate attribute': 3.083333333333333, 'parameterize attribute': 5.333333333333333, 'replace attribute with variable': 0}
Ddisappear = {'extract method': 137.66666666666669, 'inline method': 58.16666666666667, 'rename method': 490.0833333333333, 'move method': 377.0833333333333, 'move attribute': 40.0, 'pull up method': 27.5, 'pull up attribute': 15.0, 'push down method': 175.75, 'push down attribute': 12.833333333333332, 'extract superclass': 9.833333333333334, 'extract interface': 14.833333333333332, 'move class': 269.0833333333333, 'rename class': 168.08333333333331, 'extract and move method': 64.83333333333334, 'change package (move, rename, split, merge)': 0, 'move and rename class': 42.0, 'extract class': 27.833333333333336, 'extract subclass': 7.166666666666667, 'extract variable': 64.58333333333334, 'inline variable': 31.333333333333332, 'parameterize variable': 12.583333333333334, 'rename variable': 169.16666666666666, 'rename parameter': 483.3333333333333, 'rename attribute': 148.83333333333337, 'move and rename attribute': 0, 'replace variable with attribute': 25.0, 'replace attribute (with attribute)': 0, 'merge variable': 0.33333333333333337, 'merge parameter': 18.166666666666664, 'merge attribute': 1.0, 'split variable': 0, 'split parameter': 6.0, 'split attribute': 1.0, 'change variable type': 541.1666666666667, 'change parameter type': 440.33333333333337, 'change return type': 517.1666666666666, 'change attribute type': 720.9166666666667, 'extract attribute': 6.666666666666667, 'move and rename method': 79.50000000000001, 'move and inline method': 27.666666666666664, 'add method annotation': 495.8333333333333, 'remove method annotation': 116.41666666666667, 'modify method annotation': 38.25, 'add attribute annotation': 6.000000000000001, 'remove attribute annotation': 14.166666666666668, 'modify attribute annotation': 16.5, 'add class annotation': 47.916666666666664, 'remove class annotation': 13.166666666666668, 'modify class annotation': 16.166666666666668, 'add parameter annotation': 35.0, 'remove parameter annotation': 19.0, 'modify parameter annotation': 2.0, 'add variable annotation': 0, 'remove variable annotation': 3.0, 'modify variable annotation': 0, 'add parameter': 302.5833333333333, 'remove parameter': 312.83333333333337, 'reorder parameter': 6.166666666666667, 'add thrown exception type': 27.583333333333336, 'remove thrown exception type': 10.00000000000002, 'change thrown exception type': 0, 'change method access modifier': 120.33333333333333, 'change attribute access modifier': 98.91666666666669, 'encapsulate attribute': 44.416666666666664, 'parameterize attribute': 6.166666666666667, 'replace attribute with variable': 18.083333333333336}
temp = Dgenerated
# temp = Ddisappear
for each in AllRO:
    if(AllRO[each] == 0):
        AllRO[each]=1
    temp[each] = temp[each]/AllRO[each]
    if(temp[each]==0):
        temp.pop(each)
temp = sorted(temp.items(), key = lambda kv:(kv[1], kv[0]),reverse=True)
print(temp)
# Out:
# [('change attribute access modifier', 37.75), ('parameterize attribute', 5.333333333333333), ('encapsulate attribute', 3.083333333333333), ('remove variable annotation', 3.0), ('pull up method', 1.3113948919449903), ('merge variable', 1.1666666666666665), ('push down attribute', 0.4807692307692308), ('move method', 0.4307799720726112), ('move and rename class', 0.3503086419753087), ('move and rename method', 0.27583586626139817), ('extract class', 0.26519337016574585), ('move attribute', 0.2013761467889908), ('extract superclass', 0.17881944444444445), ('change thrown exception type', 0.1733333333333333), ('pull up attribute', 0.14760837070254113), ('push down method', 0.14539748953974896), ('extract subclass', 0.14015151515151514), ('extract interface', 0.1095890410958904), ('reorder parameter', 0.109375), ('remove parameter', 0.09257322175732217), ('merge parameter', 0.08695652173913043), ('split attribute', 0.08333333333333333), ('replace variable with attribute', 0.06340579710144
# ...

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.style.use('seaborn-whitegrid')
def drawDictRatio(value,name,outputPath):
    x = []
    y = []
    n=len(value)
    for each in value:
        x.append(each[0])
        y.append(each[1])
    plt.figure(figsize=(10, 10), dpi=600)
    plt.bar(x[0:n],y[0:n],label="RM detected RO")
#     plt.barh(x[0:n], y[0:n],label="RM detected RO")
    plt.ylabel("squash 2by2 RO#+ 3by3 RO#+ 4by4 RO# / normal detected RO#")
    plt.xlabel("Type of RO")
    plt.title(name)
    plt.xticks(range(len(x)),x , rotation=90)
    outputPath=outputPath+name+".png"
    plt.savefig(outputPath,dpi=400,bbox_inches='tight')
    plt.show()

# %%
outputPath="/Users/leichen/ResearchAssistant/InteractiveRebase/data/DGrefTypeGraph/"
drawDictRatio(temp,"generate_ratio",outputPath)
